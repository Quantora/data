# %%
import pandas as pd

# %%
tickers_df = pd.read_csv('../../../stock-tickers.csv')
sp500_df = pd.read_csv('./constituents.csv')

# %%
sp500_tickers_df = tickers_df[tickers_df.ticker.isin(sp500_df.ticker)]

# %%
sp500_tickers_df.to_csv('../../../sp500-tickers.csv', index=False)
sp500_tickers_df
# Out:
#      ticker                            name listed_date  sic_code  \
# 0         A       Agilent Technologies Inc.  1999-11-18    3826.0
# 6       AAL    American Airlines Group Inc.  2013-12-10    4512.0
# 12      AAP          ADVANCE AUTO PARTS INC  2001-11-29    5531.0
# 13     AAPL                      Apple Inc.  1980-12-12    3571.0
# 18     ABBV                     ABBVIE INC.  2012-12-10    2834.0
# ...     ...                             ...         ...       ...
# 5602    YUM               Yum! Brands, Inc.  1997-09-17    5812.0
# 5606    ZBH    Zimmer Biomet Holdings, Inc.  2001-08-07    3842.0
# 5607   ZBRA  Zebra Technologies Corporation  1991-08-15    3560.0
# 5623   ZION       Zions Bancorporation N.A.  1990-03-26    6021.0
# 5633    ZTS                     ZOETIS INC.  2013-02-01    2834.0
#
#         market_cap  weighted_shares
# 0     4.372096e+10     2.960720e+08
# 6     9.215595e+09     6.499009e+08
# 12    9.126257e+09     5.925372e+07
# ...
